# %%
from flask import Flask, request, jsonify
app = Flask(__name__)

import pprint, pickle
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.metrics import Accuracy

@app.route('/')
def index():
    # A welcome message to test our server
    #pkl_file = open('data.pkl', 'rb')
    #X_test_norm = pickle.load(pkl_file)
    #pkl_file.close()

    #y_test_cat = np.load('y_test_cat.npy')

    #myModel = load_model('pneu')
    #predictions2 = myModel.predict(X_test_norm)

    #m = Accuracy()
    #m.update_state(y_test_cat, np.round(predictions2))
    return <h1>'The Accuracy is', m.result().numpy()</h1>"
    return "<h1>Welcome to our medium-greeting-api!</h1>"

if __name__ == '__main__':
    # Threaded option to enable multiple instances for multiple user access support
    app.run(threaded=True, port=5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2022-04-21 19:43:27,865] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\yasee\anaconda3\lib\site-packages\werkzeug\wrappers\base_response.py", line 310, in status
#     self._status = to_native(value)
#   File "C:\Users\yasee\anaconda3\lib\site-packages\werkzeug\_compat.py", line 207, in to_native
#     return x.decode(charset, errors)
# AttributeError: 'numpy.float32' object has no attribute 'decode'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yasee\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\yasee\anaconda3\lib\site-packages\flask\app.py", line 1953, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "C:\Users\yasee\anaconda3\lib\site-packages\flask\app.py", line 1968, in finalize_request
#     response = self.make_response(rv)
#   File "C:\Users\yasee\anaconda3\lib\site-packages\flask\app.py", line 2109, in make_response
#     rv = self.response_class(rv, status=status, headers=headers)
#   File "C:\Users\yasee\anaconda3\lib\site-packages\werkzeug\wrappers\base_response.py", line 202, in __init__
#     self.status = status
#   File "C:\Users\yasee\anaconda3\lib\site-packages\werkzeug\wrappers\base_response.py", line 312, in status
#     raise TypeError("Invalid status argument")
# TypeError: Invalid status argument
# 127.0.0.1 - - [21/Apr/2022 19:43:27] "GET / HTTP/1.1" 500 -
# [2022-04-21 19:43:50,366] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\yasee\anaconda3\lib\site-packages\werkzeug\wrappers\base_response.py", line 310, in status
#     self._status = to_native(value)
#   File "C:\Users\yasee\anaconda3\lib\site-packages\werkzeug\_compat.py", line 207, in to_native
#     return x.decode(charset, errors)
# AttributeError: 'numpy.float32' object has no attribute 'decode'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yasee\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\yasee\anaconda3\lib\site-packages\flask\app.py", line 1953, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "C:\Users\yasee\anaconda3\lib\site-packages\flask\app.py", line 1968, in finalize_request
#     response = self.make_response(rv)
#   File "C:\Users\yasee\anaconda3\lib\site-packages\flask\app.py", line 2109, in make_response
#     rv = self.response_class(rv, status=status, headers=headers)
#   File "C:\Users\yasee\anaconda3\lib\site-packages\werkzeug\wrappers\base_response.py", line 202, in __init__
#     self.status = status
#   File "C:\Users\yasee\anaconda3\lib\site-packages\werkzeug\wrappers\base_response.py", line 312, in status
#     raise TypeError("Invalid status argument")
# TypeError: Invalid status argument
# 127.0.0.1 - - [21/Apr/2022 19:43:50] "GET / HTTP/1.1" 500 -
# [2022-04-21 19:43:50,457] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\yasee\anaconda3\lib\site-packages\werkzeug\wrappers\base_response.py", line 310, in status
#     self._status = to_native(value)
#   File "C:\Users\yasee\anaconda3\lib\site-packages\werkzeug\_compat.py", line 207, in to_native
#     return x.decode(charset, errors)
# AttributeError: 'numpy.float32' object has no attribute 'decode'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yasee\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\yasee\anaconda3\lib\site-packages\flask\app.py", line 1953, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "C:\Users\yasee\anaconda3\lib\site-packages\flask\app.py", line 1968, in finalize_request
#     response = self.make_response(rv)
#   File "C:\Users\yasee\anaconda3\lib\site-packages\flask\app.py", line 2109, in make_response
#     rv = self.response_class(rv, status=status, headers=headers)
#   File "C:\Users\yasee\anaconda3\lib\site-packages\werkzeug\wrappers\base_response.py", line 202, in __init__
#     self.status = status
#   File "C:\Users\yasee\anaconda3\lib\site-packages\werkzeug\wrappers\base_response.py", line 312, in status
#     raise TypeError("Invalid status argument")
# TypeError: Invalid status argument
# 127.0.0.1 - - [21/Apr/2022 19:43:50] "GET / HTTP/1.1" 500 -
